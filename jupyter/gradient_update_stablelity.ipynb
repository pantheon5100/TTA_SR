# %%
import copy
import glob
import json
import os
import shutil
from datetime import datetime

import ipdb
import numpy as np
import setGPU
import torch
import tqdm


import sys
  
# setting path
sys.path.append('..')


from tta_data import create_dataset, create_dataset_for_image_agnostic_gdn
import tta_util as util
# from tta_sr_one_cycle import TTASR
from tta_learner import Learner
from tta_options import options
# from DualSR import DualSR
# from tta_sr import TTASR
# from tta_sr_bicubic import TTASR
from tta_sr_loss_ablation import TTASR
# Out:
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "/home/zk/miniconda3/envs/work/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3397, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_40415/762650610.py", line 24, in <cell line: 24>
#     from tta_learner import Learner
#   File "/media/philipp/ssd1_2tb/nax_projects/super_resolution/TTA_SR/code/jupyter/../tta_learner.py", line 3, in <module>
#     from tta_sr import TTASR
#   File "/media/philipp/ssd1_2tb/nax_projects/super_resolution/TTA_SR/code/jupyter/../tta_sr.py", line 12, in <module>
#     from tta_model.network_swinir import define_model
#   File "/media/philipp/ssd1_2tb/nax_projects/super_resolution/TTA_SR/code/jupyter/../tta_model/network_swinir.py", line 13, in <module>
#     from timm.models.layers import DropPath, to_2tuple, trunc_normal_
#   File "/home/zk/miniconda3/envs/work/lib/python3.9/site-packages/timm/__init__.py", line 2, in <module>
#     from .models import create_model, list_models, is_model, list_modules, model_entrypoint, \
#   File "/home/zk/miniconda3/envs/work/lib/python3.9/site-packages/timm/models/__init__.py", line 1, in <module>
#     from .beit import *
#   File "/home/zk/miniconda3/envs/work/lib/python3.9/site-packages/timm/models/beit.py", line 32, in <module>
#     from .vision_transformer import checkpoint_filter_fn
#   File "/home/zk/miniconda3/envs/work/lib/python3.9/site-packages/timm/models/vision_transformer.py", line 35, in <module>
#     from timm.data import IMAGENET_DEFAULT_MEAN, IMAGENET_DEFAULT_STD, IMAGENET_INCEPTION_MEAN, IMAGENET_INCEPTION_STD
#   File "/home/zk/miniconda3/envs/work/lib/python3.9/site-packages/timm/data/__init__.py", line 5, in <module>
#     from .dataset import ImageDataset, IterableImageDataset, AugMixDataset
#   File "/home/zk/miniconda3/envs/work/lib/python3.9/site-packages/timm/data/dataset.py", line 12, in <module>
#     from .parsers import create_parser
#   File "/home/zk/miniconda3/envs/work/lib/python3.9/site-packages/timm/data/parsers/__init__.py", line 1, in <module>
#     from .parser_factory import create_parser
#   File "/home/zk/miniconda3/envs/work/lib/python3.9/site-packages/timm/data/parsers/parser_factory.py", line 3, in <module>
#     from .parser_image_folder import ParserImageFolder
#   File "/home/zk/miniconda3/envs/work/lib/python3.9/site-packages/timm/data/parsers/parser_image_folder.py", line 10, in <module>
#     from timm.utils.misc import natural_key
#   File "/home/zk/miniconda3/envs/work/lib/python3.9/site-packages/timm/utils/__init__.py", line 13, in <module>
#     from .summary import update_summary, get_outdir
#   File "/home/zk/miniconda3/envs/work/lib/python3.9/site-packages/timm/utils/summary.py", line 9, in <module>
#     import wandb
#   File "/home/zk/miniconda3/envs/work/lib/python3.9/site-packages/wandb/__init__.py", line 26, in <module>
#     from wandb import sdk as wandb_sdk
#   File "/home/zk/miniconda3/envs/work/lib/python3.9/site-packages/wandb/sdk/__init__.py", line 9, in <module>
#     from .wandb_init import _attach, init  # noqa: F401
#   File "/home/zk/miniconda3/envs/work/lib/python3.9/site-packages/wandb/sdk/wandb_init.py", line 27, in <module>
#     from . import wandb_login, wandb_setup
#   File "/home/zk/miniconda3/envs/work/lib/python3.9/site-packages/wandb/sdk/wandb_login.py", line 23, in <module>
#     from .wandb_settings import Settings, Source
#   File "/home/zk/miniconda3/envs/work/lib/python3.9/site-packages/wandb/sdk/wandb_settings.py", line 38, in <module>
#     from wandb.sdk.wandb_setup import _EarlyLogger
#   File "/home/zk/miniconda3/envs/work/lib/python3.9/site-packages/wandb/sdk/wandb_setup.py", line 28, in <module>
#     from . import wandb_manager
#   File "/home/zk/miniconda3/envs/work/lib/python3.9/site-packages/wandb/sdk/wandb_manager.py", line 12, in <module>
#     from wandb.sdk.lib.proto_util import settings_dict_from_pbmap
#   File "/home/zk/miniconda3/envs/work/lib/python3.9/site-packages/wandb/sdk/lib/proto_util.py", line 7, in <module>
#     from wandb.proto import wandb_internal_pb2 as pb
#   File "/home/zk/miniconda3/envs/work/lib/python3.9/site-packages/wandb/proto/wandb_internal_pb2.py", line 15, in <module>
#     from wandb.proto import wandb_base_pb2 as wandb_dot_proto_dot_wandb__base__pb2
#   File "/home/zk/miniconda3/envs/work/lib/python3.9/site-packages/wandb/proto/wandb_base_pb2.py", line 36, in <module>
#     _descriptor.FieldDescriptor(
#   File "/home/zk/miniconda3/envs/work/lib/python3.9/site-packages/google/protobuf/descriptor.py", line 560, in __new__
#     _message.Message._CheckCalledFromGeneratedFile()
# TypeError: Descriptors cannot not be created directly.
# If this call came from a _pb2.py file, your generated code is out of date and must be regenerated with protoc >= 3.19.0.
# If you cannot immediately regenerate your protos, some other possible workarounds are:
#  1. Downgrade the protobuf package to 3.20.x or lower.
#  2. Set PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION=python (but this will use pure-Python parsing and will be much slower).
#
# More information: https://developers.google.com/protocol-buffers/docs/news/2022-05-06#python-updates
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/zk/miniconda3/envs/work/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 1992, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(
#   File "/home/zk/miniconda3/envs/work/lib/python3.9/site-packages/IPython/core/ultratb.py", line 1118, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/home/zk/miniconda3/envs/work/lib/python3.9/site-packages/IPython/core/ultratb.py", line 1012, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/home/zk/miniconda3/envs/work/lib/python3.9/site-packages/IPython/core/ultratb.py", line 865, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "/home/zk/miniconda3/envs/work/lib/python3.9/site-packages/IPython/core/ultratb.py", line 818, in format_exception_as_a_whole
#     frames.append(self.format_record(r))
#   File "/home/zk/miniconda3/envs/work/lib/python3.9/site-packages/IPython/core/ultratb.py", line 736, in format_record
#     result += ''.join(_format_traceback_lines(frame_info.lines, Colors, self.has_colors, lvals))
#   File "/home/zk/miniconda3/envs/work/lib/python3.9/site-packages/stack_data/utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "/home/zk/miniconda3/envs/work/lib/python3.9/site-packages/stack_data/core.py", line 698, in lines
#     pieces = self.included_pieces
#   File "/home/zk/miniconda3/envs/work/lib/python3.9/site-packages/stack_data/utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "/home/zk/miniconda3/envs/work/lib/python3.9/site-packages/stack_data/core.py", line 649, in included_pieces
#     pos = scope_pieces.index(self.executing_piece)
#   File "/home/zk/miniconda3/envs/work/lib/python3.9/site-packages/stack_data/utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "/home/zk/miniconda3/envs/work/lib/python3.9/site-packages/stack_data/core.py", line 628, in executing_piece
#     return only(
#   File "/home/zk/miniconda3/envs/work/lib/python3.9/site-packages/executing/executing.py", line 164, in only
#     raise NotOneValueFound('Expected one value, found 0')
# executing.executing.NotOneValueFound: Expected one value, found 0
